# %% [markdown]
# <a href="https://colab.research.google.com/github/lautarodibartolo-ae/e8102-exploracion-de-datos/blob/main/bloque-4-regresion-y-no-parametricos/ejercitacion_bloque_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Abrir en Colab"/></a>

# %% [markdown]
# # Bloque 4 — Ejercitación**Asignatura E8102 · Exploración de datos**Ejercitación de repaso de la unidad 8 y unidad 9. La consigna completa está en el PDF del bloque.PENDIENTE — escribir la introducción.

# %% [markdown]
# ## Preparación

# %%
import pandas as pdimport matplotlib.pyplot as pltfrom scipy import stats# PENDIENTE — cargar el conjunto de datos.

# %% [markdown]
# ## 1. PENDIENTE — primer ejercicio

# %%
# PENDIENTE
